# %%
import pandas as pd
import numpy as np
from collections import Counter
import tensorflow as tf
import tensorflow_recommenders as tfrs
from tensorflow.keras.layers import Embedding, Dense, Concatenate, Input, Dropout, Flatten
from tensorflow.keras.models import Model
import os
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau, TensorBoard

# %%
# Load dataset
umkm_df = pd.read_csv('data/umkm_data.csv')
investor_df = pd.read_csv('data/investor_data.csv')
user_data = pd.read_csv('data/users_data.csv')

# %%
umkm_df = umkm_df.merge(user_data[['user_id', 'lokasi_usaha', 'pertumbuhan_pendapatan']], on='user_id', how='left')

# %%
investor_df = investor_df.merge(user_data[['user_id', 'lokasi_usaha']], on='user_id', how='left')

# %%
umkm_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100 entries, 0 to 99
# Data columns (total 8 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   user_id                 100 non-null    object
#  1   umkm_id                 100 non-null    object
#  2   kategori                100 non-null    object
#  3   model_bisnis            100 non-null    object
#  4   skala                   100 non-null    object
#  5   jangkauan               100 non-null    object
#  6   lokasi_usaha            100 non-null    object
#  7   pertumbuhan_pendapatan  100 non-null    float64
# dtypes: float64(1), object(7)
# memory usage: 7.0+ KB

# %%
investor_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100 entries, 0 to 99
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   user_id       100 non-null    object
#  1   investor_id   100 non-null    object
#  2   kategori      100 non-null    object
#  3   model_bisnis  100 non-null    object
#  4   skala         100 non-null    object
#  5   jangkauan     100 non-null    object
#  6   lokasi_usaha  100 non-null    object
# dtypes: object(7)
# memory usage: 6.2+ KB

# %%
investor_df.head()
# Out:
#                                 user_id                           investor_id  \
# 0  0026147b-6cf0-4f4b-9bc4-fe86f28c3df8  0026147b-6cf0-4f4b-9bc4-fe86f28c3df8
# 1  025e6cbc-1bd3-466a-8c34-56f3264c8597  025e6cbc-1bd3-466a-8c34-56f3264c8597
# 2  08544abb-6884-44f8-99dd-058407c95376  08544abb-6884-44f8-99dd-058407c95376
# 3  09100a78-776e-4ba2-97e6-1abdd82d0004  09100a78-776e-4ba2-97e6-1abdd82d0004
# 4  0acf62ae-69fd-40c2-8ab6-9020e82bcf2c  0acf62ae-69fd-40c2-8ab6-9020e82bcf2c
#
#      kategori model_bisnis     skala      jangkauan
# 0      Retail          B2C     Mikro  Internasional
# 1     Kuliner    Franchise     Mikro  Internasional
# 2     Fashion          B2B  Menengah          Lokal
# 3      Retail     Dropship     Mikro       Regional
# 4  Pendidikan     Reseller     Mikro          Lokal

# %%
umkm_df.head()
# Out:
#                                 user_id                               umkm_id  \
# 0  055fae89-7b46-4d94-8bd8-2f5be657a889  055fae89-7b46-4d94-8bd8-2f5be657a889
# 1  0c4bea2b-f22b-4b5c-8770-d9b2e133b485  0c4bea2b-f22b-4b5c-8770-d9b2e133b485
# 2  110c07e6-b253-46b6-8b7e-39467db9f10b  110c07e6-b253-46b6-8b7e-39467db9f10b
# 3  119d757a-7af9-4e2f-b403-3263458e7169  119d757a-7af9-4e2f-b403-3263458e7169
# 4  119f101a-7f8c-4d3b-af80-ba4d0975fe74  119f101a-7f8c-4d3b-af80-ba4d0975fe74
#
#      kategori model_bisnis     skala      jangkauan
# 0   Teknologi          B2C     Mikro       Regional
# 1       Kriya     Reseller  Menengah       Regional
# 2  Pendidikan     Dropship     Kecil          Lokal
# 3   Teknologi     Dropship     Kecil          Lokal
# 4     Kuliner     Reseller  Menengah  Internasional

# %%
# Fungsi preprocessing untuk ekstrak provinsi dari lokasi_usaha
def extract_provinsi(lokasi):
    if pd.isna(lokasi):  # Tangani nilai kosong
        return None
    try:
        # Asumsikan format "kota, provinsi"
        provinsi = lokasi.split(',')[-1].strip()  # Ambil bagian setelah koma
        return provinsi.lower()  # Case folding
    except:
        return None  # Jika format salah

# %%
# Terapkan preprocessing
umkm_df['provinsi'] = umkm_df['lokasi_usaha'].apply(extract_provinsi)

# %%
# Fungsi untuk membersihkan teks (case folding dan hapus spasi)
def clean_text(text):
    if pd.isna(text):
        return None
    return text.strip().lower()

# %%
investor_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100 entries, 0 to 99
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   user_id       100 non-null    object
#  1   investor_id   100 non-null    object
#  2   kategori      100 non-null    object
#  3   model_bisnis  100 non-null    object
#  4   skala         100 non-null    object
#  5   jangkauan     100 non-null    object
#  6   lokasi_usaha  100 non-null    object
# dtypes: object(7)
# memory usage: 6.2+ KB

# %%
# Preprocessing
# Terapkan cleaning untuk semua kolom kategorikal
for col in ['kategori', 'model_bisnis', 'skala', 'jangkauan', 'provinsi']:
    umkm_df[col] = umkm_df[col].apply(clean_text)

for col in ['kategori', 'model_bisnis', 'skala', 'jangkauan', 'lokasi_usaha']:
    investor_df[col] = investor_df[col].apply(clean_text)

# %%
# Buat vocabulary untuk setiap kolom
kategori_vocab = list(pd.unique(umkm_df['kategori'].dropna())) 
model_bisnis_vocab = list(pd.unique(umkm_df['model_bisnis'].dropna()))
skala_vocab = list(pd.unique(umkm_df['skala'].dropna()))
jangkauan_vocab = list(pd.unique(umkm_df['jangkauan'].dropna()))
lokasi_vocab = list(pd.unique(umkm_df['provinsi'].dropna()))

# %%
# Cetak vocabulary untuk verifikasi
print("Kategori vocab:", kategori_vocab)
print("Model bisnis vocab:", model_bisnis_vocab)
# Out:
# Kategori vocab: ['teknologi', 'kriya', 'pendidikan', 'kuliner', 'retail', 'jasa', 'fashion', 'kesehatan', 'agribisnis']
# Model bisnis vocab: ['b2c', 'reseller', 'dropship', 'direct-to-consumer', 'b2b', 'franchise']

# %%
# Buat StringLookup untuk mengubah string jadi indeks
kategori_lookup = tf.keras.layers.StringLookup(vocabulary=kategori_vocab, mask_token=None)
model_bisnis_lookup = tf.keras.layers.StringLookup(vocabulary=model_bisnis_vocab, mask_token=None)
skala_lookup = tf.keras.layers.StringLookup(vocabulary=skala_vocab, mask_token=None)
jangkauan_lookup = tf.keras.layers.StringLookup(vocabulary=jangkauan_vocab, mask_token=None)
lokasi_lookup = tf.keras.layers.StringLookup(vocabulary=lokasi_vocab, mask_token=None)

# %%
def encode_single_label(text_series, lookup_layer):
    """Encode single-label text to integers"""
    return lookup_layer(text_series.fillna('').astype(str)).numpy()

# %%
# Encode UMKM features
umkm_encoded = {
    'kategori': encode_single_label(umkm_df['kategori'], lokasi_lookup),
    'model_bisnis': encode_single_label(umkm_df['model_bisnis'], lokasi_lookup),
    'skala': encode_single_label(umkm_df['skala'], lokasi_lookup),
    'jangkauan': encode_single_label(umkm_df['jangkauan'], lokasi_lookup),
    'lokasi_usaha': encode_single_label(umkm_df['provinsi'], lokasi_lookup),
}

# %%
# Encode Investor features
investor_encoded = {
    'kategori': encode_single_label(investor_df['kategori'], lokasi_lookup),
    'model_bisnis': encode_single_label(investor_df['model_bisnis'], lokasi_lookup),
    'skala': encode_single_label(investor_df['skala'], lokasi_lookup),
    'jangkauan': encode_single_label(investor_df['jangkauan'], lokasi_lookup),
    'lokasi_usaha': encode_single_label(investor_df['lokasi_usaha'], lokasi_lookup),
}

# %%
def create_umkm_encoder():
    """Create UMKM encoder model"""
    kategori_input = Input(shape=(), dtype=tf.int32, name='kategori')
    model_bisnis_input = Input(shape=(), dtype=tf.int32, name='model_bisnis')
    skala_input = Input(shape=(), dtype=tf.int32, name='skala')
    jangkauan_input = Input(shape=(), dtype=tf.int32, name='jangkauan')
    lokasi_input = Input(shape=(), dtype=tf.int32, name='provinsi')
    # pertumbuhan_pendapatan_input = Input(shape=(), dtype=tf.int32, name='pertumbuhan_pendapatan')

    kategori_emb = Flatten()(Embedding(lokasi_lookup.vocabulary_size(), 16)(kategori_input))
    model_bisnis_emb = Flatten()(Embedding(lokasi_lookup.vocabulary_size(), 16)(model_bisnis_input))
    skala_emb = Flatten()(Embedding(lokasi_lookup.vocabulary_size(), 16)(skala_input))
    jangkauan_emb = Flatten()(Embedding(lokasi_lookup.vocabulary_size(), 16)(jangkauan_input))
    lokasi_emb = Flatten()(Embedding(lokasi_lookup.vocabulary_size(), 16)(lokasi_input))
    # pertumbuhan_expanded = tf.expand_dims(pertumbuhan_pendapatan_input, axis=-1)

    features = Concatenate()([
        kategori_emb, model_bisnis_emb, skala_emb, jangkauan_emb, lokasi_emb
    ])

    x = Dense(128, activation='relu')(features)
    x = Dropout(0.2)(x)
    x = Dense(64, activation='relu')(x)
    output = Dense(32, activation='relu', name='umkm_embedding')(x)

    return Model(inputs=[
        kategori_input, model_bisnis_input, skala_input, jangkauan_input, lokasi_input
    ], outputs=output, name='umkm_encoder')

# %%
def create_investor_encoder():
    """Create Investor encoder model"""
    kategori_input = Input(shape=(), dtype=tf.int32, name='kategori')
    model_bisnis_input = Input(shape=(), dtype=tf.int32, name='model_bisnis')
    skala_input = Input(shape=(), dtype=tf.int32, name='skala')
    jangkauan_input = Input(shape=(), dtype=tf.int32, name='jangkauan')
    lokasi_input = Input(shape=(), dtype=tf.int32, name='lokasi_usaha')

    kategori_emb = Flatten()(Embedding(lokasi_lookup.vocabulary_size(), 16)(kategori_input))
    model_bisnis_emb = Flatten()(Embedding(lokasi_lookup.vocabulary_size(), 16)(model_bisnis_input))
    skala_emb = Flatten()(Embedding(lokasi_lookup.vocabulary_size(), 16)(skala_input))
    jangkauan_emb = Flatten()(Embedding(lokasi_lookup.vocabulary_size(), 16)(jangkauan_input))
    lokasi_emb = Flatten()(Embedding(lokasi_lookup.vocabulary_size(), 16)(lokasi_input))


    features = Concatenate()([
        kategori_emb, model_bisnis_emb, skala_emb, jangkauan_emb, lokasi_emb
    ])

    x = Dense(128, activation='relu')(features)
    x = Dropout(0.2)(x)
    x = Dense(64, activation='relu')(x)
    output = Dense(32, activation='relu', name='investor_embedding')(x)

    return Model(inputs=[
        kategori_input, model_bisnis_input, skala_input, jangkauan_input, lokasi_input
    ], outputs=output, name='investor_encoder')

# %%
# Create encoder models
umkm_encoder = create_umkm_encoder()
investor_encoder = create_investor_encoder()

print("Models created successfully!")
print(f"UMKM encoder output shape: {umkm_encoder.output_shape}")
print(f"Investor encoder output shape: {investor_encoder.output_shape}")
# Out:
# Models created successfully!
# UMKM encoder output shape: (None, 32)
# Investor encoder output shape: (None, 32)

# %%
def create_dataset():
    """Create TensorFlow datasets using UUIDs"""
    if len(umkm_df) == 0 or len(investor_df) == 0:
        raise ValueError("Empty dataset detected. Check umkm_df and investor_df.")
    
    # Assume UUID columns are named 'umkm_id' and 'investor_id'
    # Adjust these column names if different in your DataFrames
    umkm_dataset = tf.data.Dataset.from_tensor_slices({
        'umkm_id': umkm_df['umkm_id'].astype(str).values,  # Use UUID column
        'kategori': umkm_encoded['kategori'],
        'model_bisnis': umkm_encoded['model_bisnis'],
        'skala': umkm_encoded['skala'],
        'jangkauan': umkm_encoded['jangkauan'],
        'lokasi_usaha': umkm_encoded['lokasi_usaha'],
        'pertumbuhan_pendapatan': umkm_df['pertumbuhan_pendapatan'],
    })
    
    investor_dataset = tf.data.Dataset.from_tensor_slices({
        'investor_id': investor_df['investor_id'].astype(str).values,  # Use UUID column
        'kategori': investor_encoded['kategori'],
        'model_bisnis': investor_encoded['model_bisnis'],
        'skala': investor_encoded['skala'],
        'jangkauan': investor_encoded['jangkauan'],
        'lokasi_usaha': investor_encoded['lokasi_usaha'],
    })
    
    return umkm_dataset, investor_dataset

umkm_ds, investor_ds = create_dataset()
print("Datasets created successfully!")
# Out:
# Datasets created successfully!

# %%
# ===============================
# RECOMMENDATION MODEL
# ===============================

class UMKMRecommendationModel(tfrs.Model):
    """Complete UMKM-Investor Recommendation Model"""
    
    def __init__(self, umkm_encoder, investor_encoder, umkm_ds):
        super().__init__()
        self.umkm_encoder = umkm_encoder
        self.investor_encoder = investor_encoder
        
        def map_fn(x):
            umkm_features = [
                x['kategori'],
                x['model_bisnis'],
                x['skala'],
                x['jangkauan'],
                x['lokasi_usaha'],
                # x['pertumbuhan_pendapatan']  # Uncomment if needed
            ]
            umkm_embedding = self.umkm_encoder(umkm_features)
            return umkm_embedding
        
        cached_umkm = umkm_ds.batch(1000).cache()
        self.umkm_candidates = cached_umkm.map(map_fn)
        
        self.retrieval_task = tfrs.tasks.Retrieval(
            metrics=tfrs.metrics.FactorizedTopK(
                candidates=self.umkm_candidates
            )
        )
    
    def call(self, features):
        """Forward pass"""
        investor_emb = self.investor_encoder([
            features['kategori'],
            features['model_bisnis'],
            features['skala'],
            features['jangkauan'],
            features['lokasi_usaha'],
        ])
        
        umkm_emb = self.umkm_encoder([
            features['kategori'],
            features['model_bisnis'],
            features['skala'],
            features['jangkauan'],
            features['lokasi_usaha'],
      
        ])
        
        return {
            'investor_embedding': investor_emb,
            'umkm_embedding': umkm_emb
        }
    
    def compute_loss(self, features, training=False):
        """Compute retrieval loss"""
        model_output = self(features)
        
        return self.retrieval_task(
            query_embeddings=model_output['investor_embedding'],
            candidate_embeddings=model_output['umkm_embedding']
        )

# %%
# ===============================
# TRAINING PREPARATION
# ===============================

def create_training_data():
    """Create training data by combining investor and UMKM data"""
    min_size = min(len(umkm_df), len(investor_df))
    if min_size == 0:
        raise ValueError("No data available for training. Check dataset sizes.")
    
    umkm_sample = umkm_ds.take(min_size)
    investor_sample = investor_ds.take(min_size)
    
    def combine_features(investor_features, umkm_features):
        combined = {}
        combined.update(investor_features)
        combined.update(umkm_features)
        return combined
    
    training_ds = tf.data.Dataset.zip((investor_sample, umkm_sample)).map(combine_features)
    training_ds = training_ds.shuffle(1000).batch(32).prefetch(tf.data.AUTOTUNE)
    
    return training_ds

train_ds = create_training_data()
print("Training data prepared!")

# Initialize and compile model
model = UMKMRecommendationModel(umkm_encoder, investor_encoder, umkm_ds)
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001))

print("Model compiled and ready for training!")
# Out:
# Training data prepared!
# Model compiled and ready for training!

# %%
# ===============================
# TRAINING
# ===============================

def train_model(epochs=10, checkpoint_dir='checkpoints', log_dir='logs'):
    """Train the recommendation model with callbacks"""
    print(f"Starting training for {epochs} epochs...")
    
    train_size = int(0.8 * len(list(train_ds)))
    if train_size == 0:
        raise ValueError("Training dataset is too small. Increase dataset size or adjust split ratio.")
    
    train_data = train_ds.take(train_size)
    val_data = train_ds.skip(train_size)
    
    os.makedirs(checkpoint_dir, exist_ok=True)
    os.makedirs(log_dir, exist_ok=True)
    
    callbacks = [
        ModelCheckpoint(
            filepath=os.path.join(checkpoint_dir, 'model_best.weights.h5'),
            monitor='val_loss',
            save_best_only=True,
            save_weights_only=True,
            verbose=1
        ),
        EarlyStopping(
            monitor='val_loss',
            patience=10,
            restore_best_weights=True,
            verbose=1
        ),
        ReduceLROnPlateau(
            monitor='val_loss',
            factor=0.5,
            patience=5,
            min_lr=1e-6,
            verbose=1
        ),
        TensorBoard(
            log_dir=log_dir,
            histogram_freq=1,
            write_graph=True,
            write_images=True
        )
    ]
    
    history = model.fit(
        train_data,
        validation_data=val_data,
        epochs=epochs,
        callbacks=callbacks,
        verbose=1
    )

    # Load best weights after training
    checkpoint_path = os.path.join(checkpoint_dir, 'model_best.weights.h5')
    if os.path.exists(checkpoint_path):
        model.load_weights(checkpoint_path)
        print(f"Loaded best weights from {checkpoint_path}")
    else:
        print("No checkpoint found, using final model weights")
    
    print("Training completed!")
    return history

# %%
# ===============================
# RECOMMENDATION FUNCTIONS
# ===============================

def get_recommendations(investor_id, top_k=5):
    """Get top-K UMKM recommendations for an investor using UUID"""
    # Map UUID to DataFrame index
    try:
        investor_idx = investor_df.index[investor_df['investor_id'] == investor_id].tolist()
        if not investor_idx:
            print(f"Invalid investor_id: {investor_id}. Not found in investor_df.")
            return []
        investor_idx = investor_idx[0]  # Take the first match
    except Exception as e:
        print(f"Error finding investor_id {investor_id}: {e}")
        return []
    
    # Get investor features
    investor_features = {
        'kategori': tf.constant([investor_encoded['kategori'][investor_idx]]),
        'model_bisnis': tf.constant([investor_encoded['model_bisnis'][investor_idx]]),
        'skala': tf.constant([investor_encoded['skala'][investor_idx]]),
        'jangkauan': tf.constant([investor_encoded['jangkauan'][investor_idx]]),
        'lokasi_usaha': tf.constant([investor_encoded['lokasi_usaha'][investor_idx]]),
    }
    
    # Get investor embedding
    investor_emb = investor_encoder([
        investor_features['kategori'],
        investor_features['model_bisnis'],
        investor_features['skala'],
        investor_features['jangkauan'],
        investor_features['lokasi_usaha'],
    ])
    
    # Calculate similarity with all UMKMs
    similarities = []
    for i in range(len(umkm_df)):
        umkm_features = [
            tf.constant([umkm_encoded['kategori'][i]]),
            tf.constant([umkm_encoded['model_bisnis'][i]]),
            tf.constant([umkm_encoded['skala'][i]]),
            tf.constant([umkm_encoded['jangkauan'][i]]),
            tf.constant([umkm_encoded['lokasi_usaha'][i]]),
            
        ]
        
        umkm_emb = umkm_encoder(umkm_features)
        # Use tf.keras.losses.cosine_similarity (returns negative cosine similarity, so negate it)
        similarity = -tf.keras.losses.cosine_similarity(investor_emb, umkm_emb).numpy()[0]
        similarities.append((i, similarity))
    
    # Sort by similarity (descending) and return top-K
    similarities.sort(key=lambda x: x[1], reverse=True)
    top_recommendations = similarities[:top_k]
    
    # Convert indices back to UMKM UUIDs
    return [(umkm_df['umkm_id'].iloc[umkm_id], score) for umkm_id, score in top_recommendations]

def display_recommendations(investor_id, top_k=5):
    """Display recommendations in a readable format using UUID"""
    recommendations = get_recommendations(investor_id, top_k)
    
    # Map UUID to DataFrame index for investor preferences
    try:
        investor_idx = investor_df.index[investor_df['investor_id'] == investor_id].tolist()
        if not investor_idx:
            print(f"Invalid investor_id: {investor_id}. Not found in investor_df.")
            return
        investor_idx = investor_idx[0]
    except Exception as e:
        print(f"Error finding investor_id {investor_id}: {e}")
        return
    
    print(f"\n=== Recommendations for Investor {investor_id} ===")
    print(f"Investor preferences:")
    print(f"  Location: {investor_df.iloc[investor_idx]['lokasi_usaha']}")
    print(f"  Category: {investor_df.iloc[investor_idx]['kategori']}")
    print(f"  Category: {investor_df.iloc[investor_idx]['model_bisnis']}")
    print(f"  Scale: {investor_df.iloc[investor_idx]['skala']}")
    print(f"  Jangkauan: {investor_df.iloc[investor_idx]['jangkauan']}")
    # print(f"  Max Investment: {investor_df.iloc[investor_idx]['max_investasi']:,.0f}")
    
    print(f"\nTop {top_k} recommended UMKMs:")
    for rank, (umkm_id, score) in enumerate(recommendations, 1):
        umkm_idx = umkm_df.index[umkm_df['umkm_id'] == umkm_id].tolist()[0]
        umkm_row = umkm_df.iloc[umkm_idx]
        print(f"{rank}. UMKM {umkm_id} (Score: {score:.3f})")
        print(f"   Category: {umkm_row['kategori']}")
        print(f"   Location: {umkm_row['lokasi_usaha']}")
        print(f"   Business model: {umkm_row['model_bisnis']}")
        print(f"   Skala usaha: {umkm_row['skala']}")
        print(f"   Jangkauan: {umkm_row['jangkauan']}")
        print(f"   Pertumbuhan pendapatan: {umkm_row['pertumbuhan_pendapatan']:.2f}%")
        print()

# %%
# Run training
history = train_model(epochs=100, checkpoint_dir='checkpoints', log_dir='logs')
# Out:
# Starting training for 100 epochs...
# Epoch 1/100
# 3/3 [==============================] - ETA: 0s - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.6146 - factorized_top_k/top_100_categorical_accuracy: 0.9583 - loss: 110.8992 - regularization_loss: 0.0000e+00 - total_loss: 110.8992
# Epoch 1: val_loss improved from inf to 5.54267, saving model to checkpoints\model_best.weights.h5
# 3/3 [==============================] - 7s 810ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.6146 - factorized_top_k/top_100_categorical_accuracy: 0.9583 - loss: 110.8981 - regularization_loss: 0.0000e+00 - total_loss: 110.8981 - val_factorized_top_k/top_1_categorical_accuracy: 0.7500 - val_factorized_top_k/top_5_categorical_accuracy: 0.7500 - val_factorized_top_k/top_10_categorical_accuracy: 0.7500 - val_factorized_top_k/top_50_categorical_accuracy: 1.0000 - val_factorized_top_k/top_100_categorical_accuracy: 1.0000 - val_loss: 5.5427 - val_regularization_loss: 0.0000e+00 - val_total_loss: 5.5427 - lr: 0.0010
# Epoch 2/100
# 3/3 [==============================] - ETA: 0s - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.5938 - factorized_top_k/top_100_categorical_accuracy: 0.8750 - loss: 110.8799 - regularization_loss: 0.0000e+00 - total_loss: 110.8799
# Epoch 2: val_loss improved from 5.54267 to 5.53991, saving model to checkpoints\model_best.weights.h5
# 3/3 [==============================] - 1s 379ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.5938 - factorized_top_k/top_100_categorical_accuracy: 0.8750 - loss: 110.8774 - regularization_loss: 0.0000e+00 - total_loss: 110.8774 - val_factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - val_factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - val_factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - val_factorized_top_k/top_50_categorical_accuracy: 0.7500 - val_factorized_top_k/top_100_categorical_accuracy: 1.0000 - val_loss: 5.5399 - val_regularization_loss: 0.0000e+00 - val_total_loss: 5.5399 - lr: 0.0010
# Epoch 3/100
# 3/3 [==============================] - ETA: 0s - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.6146 - factorized_top_k/top_100_categorical_accuracy: 0.9271 - loss: 110.8460 - regularization_loss: 0.0000e+00 - total_loss: 110.8460
# Epoch 3: val_loss improved from 5.53991 to 5.53368, saving model to checkpoints\model_best.weights.h5
# 3/3 [==============================] - 1s 355ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.6146 - factorized_top_k/top_100_categorical_accuracy: 0.9271 - loss: 110.8406 - regularization_loss: 0.0000e+00 - total_loss: 110.8406 - val_factorized_top_k/top_1_categorical_accuracy: 0.5000 - val_factorized_top_k/top_5_categorical_accuracy: 0.5000 - val_factorized_top_k/top_10_categorical_accuracy: 0.5000 - val_factorized_top_k/top_50_categorical_accuracy: 1.0000 - val_factorized_top_k/top_100_categorical_accuracy: 1.0000 - val_loss: 5.5337 - val_regularization_loss: 0.0000e+00 - val_total_loss: 5.5337 - lr: 0.0010
# Epoch 4/100
# 3/3 [==============================] - ETA: 0s - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.6250 - factorized_top_k/top_100_categorical_accuracy: 0.9583 - loss: 110.7882 - regularization_loss: 0.0000e+00 - total_loss: 110.7882
# Epoch 4: val_loss improved from 5.53368 to 5.52452, saving model to checkpoints\model_best.weights.h5
# 3/3 [==============================] - 1s 365ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.6250 - factorized_top_k/top_100_categorical_accuracy: 0.9583 - loss: 110.7812 - regularization_loss: 0.0000e+00 - total_loss: 110.7812 - val_factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - val_factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - val_factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - val_factorized_top_k/top_50_categorical_accuracy: 0.5000 - val_factorized_top_k/top_100_categorical_accuracy: 1.0000 - val_loss: 5.5245 - val_regularization_loss: 0.0000e+00 - val_total_loss: 5.5245 - lr: 0.0010
# Epoch 5/100
# 3/3 [==============================] - ETA: 0s - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.6458 - factorized_top_k/top_100_categorical_accuracy: 1.0000 - loss: 110.6873 - regularization_loss: 0.0000e+00 - total_loss: 110.6873
# Epoch 5: val_loss improved from 5.52452 to 5.52217, saving model to checkpoints\model_best.weights.h5
# 3/3 [==============================] - 1s 357ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.6458 - factorized_top_k/top_100_categorical_accuracy: 1.0000 - loss: 110.6675 - regularization_loss: 0.0000e+00 - total_loss: 110.6675 - val_factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - val_factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - val_factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - val_factorized_top_k/top_50_categorical_accuracy: 0.7500 - val_factorized_top_k/top_100_categorical_accuracy: 1.0000 - val_loss: 5.5222 - val_regularization_loss: 0.0000e+00 - val_total_loss: 5.5222 - lr: 0.0010
# Epoch 6/100
# 3/3 [==============================] - ETA: 0s - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.7708 - factorized_top_k/top_100_categorical_accuracy: 0.8958 - loss: 110.5265 - regularization_loss: 0.0000e+00 - total_loss: 110.5265
# Epoch 6: val_loss improved from 5.52217 to 5.47745, saving model to checkpoints\model_best.weights.h5
# 3/3 [==============================] - 1s 364ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.7708 - factorized_top_k/top_100_categorical_accuracy: 0.8958 - loss: 110.5119 - regularization_loss: 0.0000e+00 - total_loss: 110.5119 - val_factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - val_factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - val_factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - val_factorized_top_k/top_50_categorical_accuracy: 1.0000 - val_factorized_top_k/top_100_categorical_accuracy: 1.0000 - val_loss: 5.4774 - val_regularization_loss: 0.0000e+00 - val_total_loss: 5.4774 - lr: 0.0010
# Epoch 7/100
# 3/3 [==============================] - ETA: 0s - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.8125 - factorized_top_k/top_100_categorical_accuracy: 1.0000 - loss: 110.2545 - regularization_loss: 0.0000e+00 - total_loss: 110.2545
# Epoch 7: val_loss improved from 5.47745 to 5.41824, saving model to checkpoints\model_best.weights.h5
# 3/3 [==============================] - 1s 350ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.8125 - factorized_top_k/top_100_categorical_accuracy: 1.0000 - loss: 110.2636 - regularization_loss: 0.0000e+00 - total_loss: 110.2636 - val_factorized_top_k/top_1_categorical_accuracy: 0.2500 - val_factorized_top_k/top_5_categorical_accuracy: 0.2500 - val_factorized_top_k/top_10_categorical_accuracy: 0.2500 - val_factorized_top_k/top_50_categorical_accuracy: 1.0000 - val_factorized_top_k/top_100_categorical_accuracy: 1.0000 - val_loss: 5.4182 - val_regularization_loss: 0.0000e+00 - val_total_loss: 5.4182 - lr: 0.0010
# Epoch 8/100
# 3/3 [==============================] - ETA: 0s - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.8125 - factorized_top_k/top_100_categorical_accuracy: 1.0000 - loss: 109.7308 - regularization_loss: 0.0000e+00 - total_loss: 109.7308
# Epoch 8: val_loss improved from 5.41824 to 5.29634, saving model to checkpoints\model_best.weights.h5
# 3/3 [==============================] - 1s 373ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.8125 - factorized_top_k/top_100_categorical_accuracy: 1.0000 - loss: 109.6807 - regularization_loss: 0.0000e+00 - total_loss: 109.6807 - val_factorized_top_k/top_1_categorical_accuracy: 0.2500 - val_factorized_top_k/top_5_categorical_accuracy: 0.2500 - val_factorized_top_k/top_10_categorical_accuracy: 0.2500 - val_factorized_top_k/top_50_categorical_accuracy: 1.0000 - val_factorized_top_k/top_100_categorical_accuracy: 1.0000 - val_loss: 5.2963 - val_regularization_loss: 0.0000e+00 - val_total_loss: 5.2963 - lr: 0.0010
# Epoch 9/100
# 3/3 [==============================] - ETA: 0s - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.8021 - factorized_top_k/top_100_categorical_accuracy: 1.0000 - loss: 108.8345 - regularization_loss: 0.0000e+00 - total_loss: 108.8345
# Epoch 9: val_loss did not improve from 5.29634
# 3/3 [==============================] - 1s 346ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.8021 - factorized_top_k/top_100_categorical_accuracy: 1.0000 - loss: 108.8020 - regularization_loss: 0.0000e+00 - total_loss: 108.8020 - val_factorized_top_k/top_1_categorical_accuracy: 0.2500 - val_factorized_top_k/top_5_categorical_accuracy: 0.2500 - val_factorized_top_k/top_10_categorical_accuracy: 0.2500 - val_factorized_top_k/top_50_categorical_accuracy: 1.0000 - val_factorized_top_k/top_100_categorical_accuracy: 1.0000 - val_loss: 5.5040 - val_regularization_loss: 0.0000e+00 - val_total_loss: 5.5040 - lr: 0.0010
# Epoch 10/100
# 3/3 [==============================] - ETA: 0s - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.9375 - factorized_top_k/top_100_categorical_accuracy: 1.0000 - loss: 107.4926 - regularization_loss: 0.0000e+00 - total_loss: 107.4926
# Epoch 10: val_loss improved from 5.29634 to 4.78765, saving model to checkpoints\model_best.weights.h5
# 3/3 [==============================] - 1s 370ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.9375 - factorized_top_k/top_100_categorical_accuracy: 1.0000 - loss: 107.3012 - regularization_loss: 0.0000e+00 - total_loss: 107.3012 - val_factorized_top_k/top_1_categorical_accuracy: 0.2500 - val_factorized_top_k/top_5_categorical_accuracy: 0.2500 - val_factorized_top_k/top_10_categorical_accuracy: 0.2500 - val_factorized_top_k/top_50_categorical_accuracy: 1.0000 - val_factorized_top_k/top_100_categorical_accuracy: 1.0000 - val_loss: 4.7876 - val_regularization_loss: 0.0000e+00 - val_total_loss: 4.7876 - lr: 0.0010
# Epoch 11/100
# 3/3 [==============================] - ETA: 0s - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.9479 - factorized_top_k/top_100_categorical_accuracy: 1.0000 - loss: 104.7646 - regularization_loss: 0.0000e+00 - total_loss: 104.7646
# Epoch 11: val_loss improved from 4.78765 to 4.52898, saving model to checkpoints\model_best.weights.h5
# 3/3 [==============================] - 1s 386ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.9479 - factorized_top_k/top_100_categorical_accuracy: 1.0000 - loss: 104.4840 - regularization_loss: 0.0000e+00 - total_loss: 104.4840 - val_factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - val_factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - val_factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - val_factorized_top_k/top_50_categorical_accuracy: 1.0000 - val_factorized_top_k/top_100_categorical_accuracy: 1.0000 - val_loss: 4.5290 - val_regularization_loss: 0.0000e+00 - val_total_loss: 4.5290 - lr: 0.0010
# Epoch 12/100
# 3/3 [==============================] - ETA: 0s - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.9375 - factorized_top_k/top_100_categorical_accuracy: 1.0000 - loss: 101.6213 - regularization_loss: 0.0000e+00 - total_loss: 101.6213
# Epoch 12: val_loss improved from 4.52898 to 4.26667, saving model to checkpoints\model_best.weights.h5
# 3/3 [==============================] - 1s 368ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.9375 - factorized_top_k/top_100_categorical_accuracy: 1.0000 - loss: 101.5158 - regularization_loss: 0.0000e+00 - total_loss: 101.5158 - val_factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - val_factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - val_factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - val_factorized_top_k/top_50_categorical_accuracy: 1.0000 - val_factorized_top_k/top_100_categorical_accuracy: 1.0000 - val_loss: 4.2667 - val_regularization_loss: 0.0000e+00 - val_total_loss: 4.2667 - lr: 0.0010
# Epoch 13/100
# 3/3 [==============================] - ETA: 0s - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.9479 - factorized_top_k/top_100_categorical_accuracy: 1.0000 - loss: 97.3258 - regularization_loss: 0.0000e+00 - total_loss: 97.3258
# Epoch 13: val_loss improved from 4.26667 to 3.86352, saving model to checkpoints\model_best.weights.h5
# 3/3 [==============================] - 1s 378ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.9479 - factorized_top_k/top_100_categorical_accuracy: 1.0000 - loss: 97.2009 - regularization_loss: 0.0000e+00 - total_loss: 97.2009 - val_factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - val_factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - val_factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - val_factorized_top_k/top_50_categorical_accuracy: 1.0000 - val_factorized_top_k/top_100_categorical_accuracy: 1.0000 - val_loss: 3.8635 - val_regularization_loss: 0.0000e+00 - val_total_loss: 3.8635 - lr: 0.0010
# Epoch 14/100
# 3/3 [==============================] - ETA: 0s - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.9375 - factorized_top_k/top_100_categorical_accuracy: 0.9792 - loss: 92.8217 - regularization_loss: 0.0000e+00 - total_loss: 92.8217
# Epoch 14: val_loss improved from 3.86352 to 3.39235, saving model to checkpoints\model_best.weights.h5
# 3/3 [==============================] - 1s 358ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.9375 - factorized_top_k/top_100_categorical_accuracy: 0.9792 - loss: 92.5382 - regularization_loss: 0.0000e+00 - total_loss: 92.5382 - val_factorized_top_k/top_1_categorical_accuracy: 0.5000 - val_factorized_top_k/top_5_categorical_accuracy: 0.5000 - val_factorized_top_k/top_10_categorical_accuracy: 0.5000 - val_factorized_top_k/top_50_categorical_accuracy: 1.0000 - val_factorized_top_k/top_100_categorical_accuracy: 1.0000 - val_loss: 3.3924 - val_regularization_loss: 0.0000e+00 - val_total_loss: 3.3924 - lr: 0.0010
# Epoch 15/100
# 3/3 [==============================] - ETA: 0s - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.9375 - factorized_top_k/top_100_categorical_accuracy: 1.0000 - loss: 90.0279 - regularization_loss: 0.0000e+00 - total_loss: 90.0279
# Epoch 15: val_loss improved from 3.39235 to 2.75860, saving model to checkpoints\model_best.weights.h5
# 3/3 [==============================] - 1s 409ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.9375 - factorized_top_k/top_100_categorical_accuracy: 1.0000 - loss: 89.8310 - regularization_loss: 0.0000e+00 - total_loss: 89.8310 - val_factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - val_factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - val_factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - val_factorized_top_k/top_50_categorical_accuracy: 1.0000 - val_factorized_top_k/top_100_categorical_accuracy: 1.0000 - val_loss: 2.7586 - val_regularization_loss: 0.0000e+00 - val_total_loss: 2.7586 - lr: 0.0010
# Epoch 16/100
# 3/3 [==============================] - ETA: 0s - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.9375 - factorized_top_k/top_100_categorical_accuracy: 1.0000 - loss: 88.5037 - regularization_loss: 0.0000e+00 - total_loss: 88.5037
# Epoch 16: val_loss did not improve from 2.75860
# 3/3 [==============================] - 1s 355ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.9375 - factorized_top_k/top_100_categorical_accuracy: 1.0000 - loss: 88.2703 - regularization_loss: 0.0000e+00 - total_loss: 88.2703 - val_factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - val_factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - val_factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - val_factorized_top_k/top_50_categorical_accuracy: 1.0000 - val_factorized_top_k/top_100_categorical_accuracy: 1.0000 - val_loss: 4.8605 - val_regularization_loss: 0.0000e+00 - val_total_loss: 4.8605 - lr: 0.0010
# Epoch 17/100
# 3/3 [==============================] - ETA: 0s - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.9792 - factorized_top_k/top_100_categorical_accuracy: 1.0000 - loss: 88.2364 - regularization_loss: 0.0000e+00 - total_loss: 88.2364
# Epoch 17: val_loss did not improve from 2.75860
# 3/3 [==============================] - 1s 349ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.9792 - factorized_top_k/top_100_categorical_accuracy: 1.0000 - loss: 88.2174 - regularization_loss: 0.0000e+00 - total_loss: 88.2174 - val_factorized_top_k/top_1_categorical_accuracy: 0.2500 - val_factorized_top_k/top_5_categorical_accuracy: 0.2500 - val_factorized_top_k/top_10_categorical_accuracy: 0.2500 - val_factorized_top_k/top_50_categorical_accuracy: 1.0000 - val_factorized_top_k/top_100_categorical_accuracy: 1.0000 - val_loss: 3.2686 - val_regularization_loss: 0.0000e+00 - val_total_loss: 3.2686 - lr: 0.0010
# Epoch 18/100
# 3/3 [==============================] - ETA: 0s - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.9896 - factorized_top_k/top_100_categorical_accuracy: 1.0000 - loss: 86.2343 - regularization_loss: 0.0000e+00 - total_loss: 86.2343
# Epoch 18: val_loss improved from 2.75860 to 2.34691, saving model to checkpoints\model_best.weights.h5
# 3/3 [==============================] - 1s 386ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.9896 - factorized_top_k/top_100_categorical_accuracy: 1.0000 - loss: 86.2838 - regularization_loss: 0.0000e+00 - total_loss: 86.2838 - val_factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - val_factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - val_factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - val_factorized_top_k/top_50_categorical_accuracy: 1.0000 - val_factorized_top_k/top_100_categorical_accuracy: 1.0000 - val_loss: 2.3469 - val_regularization_loss: 0.0000e+00 - val_total_loss: 2.3469 - lr: 0.0010
# Epoch 19/100
# 3/3 [==============================] - ETA: 0s - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0521 - factorized_top_k/top_50_categorical_accuracy: 1.0000 - factorized_top_k/top_100_categorical_accuracy: 1.0000 - loss: 84.4859 - regularization_loss: 0.0000e+00 - total_loss: 84.4859
# Epoch 19: val_loss did not improve from 2.34691
# 3/3 [==============================] - 1s 357ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0521 - factorized_top_k/top_50_categorical_accuracy: 1.0000 - factorized_top_k/top_100_categorical_accuracy: 1.0000 - loss: 84.3801 - regularization_loss: 0.0000e+00 - total_loss: 84.3801 - val_factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - val_factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - val_factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - val_factorized_top_k/top_50_categorical_accuracy: 1.0000 - val_factorized_top_k/top_100_categorical_accuracy: 1.0000 - val_loss: 3.2906 - val_regularization_loss: 0.0000e+00 - val_total_loss: 3.2906 - lr: 0.0010
# Epoch 20/100
# 3/3 [==============================] - ETA: 0s - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0625 - factorized_top_k/top_50_categorical_accuracy: 1.0000 - factorized_top_k/top_100_categorical_accuracy: 1.0000 - loss: 83.5404 - regularization_loss: 0.0000e+00 - total_loss: 83.5404
# Epoch 20: val_loss did not improve from 2.34691
# 3/3 [==============================] - 1s 366ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0625 - factorized_top_k/top_50_categorical_accuracy: 1.0000 - factorized_top_k/top_100_categorical_accuracy: 1.0000 - loss: 84.4337 - regularization_loss: 0.0000e+00 - total_loss: 84.4337 - val_factorized_top_k/top_1_categorical_accuracy: 0.2500 - val_factorized_top_k/top_5_categorical_accuracy: 0.2500 - val_factorized_top_k/top_10_categorical_accuracy: 0.7500 - val_factorized_top_k/top_50_categorical_accuracy: 1.0000 - val_factorized_top_k/top_100_categorical_accuracy: 1.0000 - val_loss: 2.7304 - val_regularization_loss: 0.0000e+00 - val_total_loss: 2.7304 - lr: 0.0010
# Epoch 21/100
# 3/3 [==============================] - ETA: 0s - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0625 - factorized_top_k/top_50_categorical_accuracy: 1.0000 - factorized_top_k/top_100_categorical_accuracy: 1.0000 - loss: 80.0362 - regularization_loss: 0.0000e+00 - total_loss: 80.0362
# Epoch 21: val_loss improved from 2.34691 to 1.89519, saving model to checkpoints\model_best.weights.h5
# 3/3 [==============================] - 1s 375ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0625 - factorized_top_k/top_50_categorical_accuracy: 1.0000 - factorized_top_k/top_100_categorical_accuracy: 1.0000 - loss: 80.4467 - regularization_loss: 0.0000e+00 - total_loss: 80.4467 - val_factorized_top_k/top_1_categorical_accuracy: 0.2500 - val_factorized_top_k/top_5_categorical_accuracy: 0.2500 - val_factorized_top_k/top_10_categorical_accuracy: 0.2500 - val_factorized_top_k/top_50_categorical_accuracy: 1.0000 - val_factorized_top_k/top_100_categorical_accuracy: 1.0000 - val_loss: 1.8952 - val_regularization_loss: 0.0000e+00 - val_total_loss: 1.8952 - lr: 0.0010
# Epoch 22/100
# 3/3 [==============================] - ETA: 0s - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0312 - factorized_top_k/top_50_categorical_accuracy: 1.0000 - factorized_top_k/top_100_categorical_accuracy: 1.0000 - loss: 78.3108 - regularization_loss: 0.0000e+00 - total_loss: 78.3108
# Epoch 22: val_loss improved from 1.89519 to 1.28809, saving model to checkpoints\model_best.weights.h5
# 3/3 [==============================] - 1s 390ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0312 - factorized_top_k/top_50_categorical_accuracy: 1.0000 - factorized_top_k/top_100_categorical_accuracy: 1.0000 - loss: 79.2837 - regularization_loss: 0.0000e+00 - total_loss: 79.2837 - val_factorized_top_k/top_1_categorical_accuracy: 0.5000 - val_factorized_top_k/top_5_categorical_accuracy: 0.5000 - val_factorized_top_k/top_10_categorical_accuracy: 0.5000 - val_factorized_top_k/top_50_categorical_accuracy: 1.0000 - val_factorized_top_k/top_100_categorical_accuracy: 1.0000 - val_loss: 1.2881 - val_regularization_loss: 0.0000e+00 - val_total_loss: 1.2881 - lr: 0.0010
# Epoch 23/100
# 3/3 [==============================] - ETA: 0s - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0312 - factorized_top_k/top_50_categorical_accuracy: 1.0000 - factorized_top_k/top_100_categorical_accuracy: 1.0000 - loss: 76.5100 - regularization_loss: 0.0000e+00 - total_loss: 76.5100
# Epoch 23: val_loss did not improve from 1.28809
# 3/3 [==============================] - 1s 375ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0312 - factorized_top_k/top_50_categorical_accuracy: 1.0000 - factorized_top_k/top_100_categorical_accuracy: 1.0000 - loss: 75.9690 - regularization_loss: 0.0000e+00 - total_loss: 75.9690 - val_factorized_top_k/top_1_categorical_accuracy: 0.2500 - val_factorized_top_k/top_5_categorical_accuracy: 0.2500 - val_factorized_top_k/top_10_categorical_accuracy: 0.2500 - val_factorized_top_k/top_50_categorical_accuracy: 1.0000 - val_factorized_top_k/top_100_categorical_accuracy: 1.0000 - val_loss: 1.4495 - val_regularization_loss: 0.0000e+00 - val_total_loss: 1.4495 - lr: 0.0010
# Epoch 24/100
# 3/3 [==============================] - ETA: 0s - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0417 - factorized_top_k/top_50_categorical_accuracy: 0.9271 - factorized_top_k/top_100_categorical_accuracy: 1.0000 - loss: 72.0283 - regularization_loss: 0.0000e+00 - total_loss: 72.0283
# Epoch 24: val_loss did not improve from 1.28809
# 3/3 [==============================] - 1s 357ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0417 - factorized_top_k/top_50_categorical_accuracy: 0.9271 - factorized_top_k/top_100_categorical_accuracy: 1.0000 - loss: 71.7071 - regularization_loss: 0.0000e+00 - total_loss: 71.7071 - val_factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - val_factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - val_factorized_top_k/top_10_categorical_accuracy: 0.5000 - val_factorized_top_k/top_50_categorical_accuracy: 1.0000 - val_factorized_top_k/top_100_categorical_accuracy: 1.0000 - val_loss: 2.9782 - val_regularization_loss: 0.0000e+00 - val_total_loss: 2.9782 - lr: 0.0010
# Epoch 25/100
# 3/3 [==============================] - ETA: 0s - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0625 - factorized_top_k/top_50_categorical_accuracy: 1.0000 - factorized_top_k/top_100_categorical_accuracy: 1.0000 - loss: 69.6124 - regularization_loss: 0.0000e+00 - total_loss: 69.6124
# Epoch 25: val_loss did not improve from 1.28809
# 3/3 [==============================] - 1s 357ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0625 - factorized_top_k/top_50_categorical_accuracy: 1.0000 - factorized_top_k/top_100_categorical_accuracy: 1.0000 - loss: 69.6719 - regularization_loss: 0.0000e+00 - total_loss: 69.6719 - val_factorized_top_k/top_1_categorical_accuracy: 0.2500 - val_factorized_top_k/top_5_categorical_accuracy: 0.2500 - val_factorized_top_k/top_10_categorical_accuracy: 0.5000 - val_factorized_top_k/top_50_categorical_accuracy: 1.0000 - val_factorized_top_k/top_100_categorical_accuracy: 1.0000 - val_loss: 1.5498 - val_regularization_loss: 0.0000e+00 - val_total_loss: 1.5498 - lr: 0.0010
# Epoch 26/100
# 3/3 [==============================] - ETA: 0s - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0521 - factorized_top_k/top_50_categorical_accuracy: 1.0000 - factorized_top_k/top_100_categorical_accuracy: 1.0000 - loss: 68.9351 - regularization_loss: 0.0000e+00 - total_loss: 68.9351
# Epoch 26: val_loss did not improve from 1.28809
# 3/3 [==============================] - 1s 357ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0521 - factorized_top_k/top_50_categorical_accuracy: 1.0000 - factorized_top_k/top_100_categorical_accuracy: 1.0000 - loss: 69.2798 - regularization_loss: 0.0000e+00 - total_loss: 69.2798 - val_factorized_top_k/top_1_categorical_accuracy: 1.0000 - val_factorized_top_k/top_5_categorical_accuracy: 1.0000 - val_factorized_top_k/top_10_categorical_accuracy: 1.0000 - val_factorized_top_k/top_50_categorical_accuracy: 1.0000 - val_factorized_top_k/top_100_categorical_accuracy: 1.0000 - val_loss: 1.3887 - val_regularization_loss: 0.0000e+00 - val_total_loss: 1.3887 - lr: 0.0010
# Epoch 27/100
# 3/3 [==============================] - ETA: 0s - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 1.0000 - factorized_top_k/top_100_categorical_accuracy: 1.0000 - loss: 65.2720 - regularization_loss: 0.0000e+00 - total_loss: 65.2720
# Epoch 27: val_loss did not improve from 1.28809
#
# Epoch 27: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 3/3 [==============================] - 1s 350ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 1.0000 - factorized_top_k/top_100_categorical_accuracy: 1.0000 - loss: 64.9442 - regularization_loss: 0.0000e+00 - total_loss: 64.9442 - val_factorized_top_k/top_1_categorical_accuracy: 0.5000 - val_factorized_top_k/top_5_categorical_accuracy: 0.5000 - val_factorized_top_k/top_10_categorical_accuracy: 0.5000 - val_factorized_top_k/top_50_categorical_accuracy: 1.0000 - val_factorized_top_k/top_100_categorical_accuracy: 1.0000 - val_loss: 3.2309 - val_regularization_loss: 0.0000e+00 - val_total_loss: 3.2309 - lr: 0.0010
# Epoch 28/100
# 3/3 [==============================] - ETA: 0s - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0625 - factorized_top_k/top_50_categorical_accuracy: 1.0000 - factorized_top_k/top_100_categorical_accuracy: 1.0000 - loss: 65.2496 - regularization_loss: 0.0000e+00 - total_loss: 65.2496
# Epoch 28: val_loss improved from 1.28809 to 0.17289, saving model to checkpoints\model_best.weights.h5
# 3/3 [==============================] - 1s 366ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0625 - factorized_top_k/top_50_categorical_accuracy: 1.0000 - factorized_top_k/top_100_categorical_accuracy: 1.0000 - loss: 64.8451 - regularization_loss: 0.0000e+00 - total_loss: 64.8451 - val_factorized_top_k/top_1_categorical_accuracy: 0.5000 - val_factorized_top_k/top_5_categorical_accuracy: 0.5000 - val_factorized_top_k/top_10_categorical_accuracy: 0.5000 - val_factorized_top_k/top_50_categorical_accuracy: 1.0000 - val_factorized_top_k/top_100_categorical_accuracy: 1.0000 - val_loss: 0.1729 - val_regularization_loss: 0.0000e+00 - val_total_loss: 0.1729 - lr: 5.0000e-04
# Epoch 29/100
# 3/3 [==============================] - ETA: 0s - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0625 - factorized_top_k/top_50_categorical_accuracy: 1.0000 - factorized_top_k/top_100_categorical_accuracy: 1.0000 - loss: 62.1613 - regularization_loss: 0.0000e+00 - total_loss: 62.1613
# Epoch 29: val_loss did not improve from 0.17289
# 3/3 [==============================] - 1s 346ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0625 - factorized_top_k/top_50_categorical_accuracy: 1.0000 - factorized_top_k/top_100_categorical_accuracy: 1.0000 - loss: 62.0781 - regularization_loss: 0.0000e+00 - total_loss: 62.0781 - val_factorized_top_k/top_1_categorical_accuracy: 0.7500 - val_factorized_top_k/top_5_categorical_accuracy: 0.7500 - val_factorized_top_k/top_10_categorical_accuracy: 0.7500 - val_factorized_top_k/top_50_categorical_accuracy: 1.0000 - val_factorized_top_k/top_100_categorical_accuracy: 1.0000 - val_loss: 1.4529 - val_regularization_loss: 0.0000e+00 - val_total_loss: 1.4529 - lr: 5.0000e-04
# Epoch 30/100
# 3/3 [==============================] - ETA: 0s - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0625 - factorized_top_k/top_50_categorical_accuracy: 1.0000 - factorized_top_k/top_100_categorical_accuracy: 1.0000 - loss: 63.2612 - regularization_loss: 0.0000e+00 - total_loss: 63.2612
# Epoch 30: val_loss did not improve from 0.17289
# 3/3 [==============================] - 1s 347ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0625 - factorized_top_k/top_50_categorical_accuracy: 1.0000 - factorized_top_k/top_100_categorical_accuracy: 1.0000 - loss: 63.8100 - regularization_loss: 0.0000e+00 - total_loss: 63.8100 - val_factorized_top_k/top_1_categorical_accuracy: 1.0000 - val_factorized_top_k/top_5_categorical_accuracy: 1.0000 - val_factorized_top_k/top_10_categorical_accuracy: 1.0000 - val_factorized_top_k/top_50_categorical_accuracy: 1.0000 - val_factorized_top_k/top_100_categorical_accuracy: 1.0000 - val_loss: 1.5224 - val_regularization_loss: 0.0000e+00 - val_total_loss: 1.5224 - lr: 5.0000e-04
# Epoch 31/100
# 3/3 [==============================] - ETA: 0s - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0625 - factorized_top_k/top_50_categorical_accuracy: 1.0000 - factorized_top_k/top_100_categorical_accuracy: 1.0000 - loss: 61.1003 - regularization_loss: 0.0000e+00 - total_loss: 61.1003
# Epoch 31: val_loss did not improve from 0.17289
# 3/3 [==============================] - 1s 369ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0625 - factorized_top_k/top_50_categorical_accuracy: 1.0000 - factorized_top_k/top_100_categorical_accuracy: 1.0000 - loss: 60.5937 - regularization_loss: 0.0000e+00 - total_loss: 60.5937 - val_factorized_top_k/top_1_categorical_accuracy: 0.7500 - val_factorized_top_k/top_5_categorical_accuracy: 0.7500 - val_factorized_top_k/top_10_categorical_accuracy: 1.0000 - val_factorized_top_k/top_50_categorical_accuracy: 1.0000 - val_factorized_top_k/top_100_categorical_accuracy: 1.0000 - val_loss: 1.9970 - val_regularization_loss: 0.0000e+00 - val_total_loss: 1.9970 - lr: 5.0000e-04
# Epoch 32/100
# 3/3 [==============================] - ETA: 0s - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0625 - factorized_top_k/top_50_categorical_accuracy: 1.0000 - factorized_top_k/top_100_categorical_accuracy: 1.0000 - loss: 58.3887 - regularization_loss: 0.0000e+00 - total_loss: 58.3887
# Epoch 32: val_loss did not improve from 0.17289
# 3/3 [==============================] - 1s 351ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0625 - factorized_top_k/top_50_categorical_accuracy: 1.0000 - factorized_top_k/top_100_categorical_accuracy: 1.0000 - loss: 58.3003 - regularization_loss: 0.0000e+00 - total_loss: 58.3003 - val_factorized_top_k/top_1_categorical_accuracy: 0.7500 - val_factorized_top_k/top_5_categorical_accuracy: 0.7500 - val_factorized_top_k/top_10_categorical_accuracy: 0.7500 - val_factorized_top_k/top_50_categorical_accuracy: 1.0000 - val_factorized_top_k/top_100_categorical_accuracy: 1.0000 - val_loss: 2.7742 - val_regularization_loss: 0.0000e+00 - val_total_loss: 2.7742 - lr: 5.0000e-04
# Epoch 33/100
# 3/3 [==============================] - ETA: 0s - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0521 - factorized_top_k/top_50_categorical_accuracy: 1.0000 - factorized_top_k/top_100_categorical_accuracy: 1.0000 - loss: 57.7042 - regularization_loss: 0.0000e+00 - total_loss: 57.7042
# Epoch 33: val_loss did not improve from 0.17289
#
# Epoch 33: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 3/3 [==============================] - 1s 357ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0521 - factorized_top_k/top_50_categorical_accuracy: 1.0000 - factorized_top_k/top_100_categorical_accuracy: 1.0000 - loss: 56.9704 - regularization_loss: 0.0000e+00 - total_loss: 56.9704 - val_factorized_top_k/top_1_categorical_accuracy: 0.7500 - val_factorized_top_k/top_5_categorical_accuracy: 0.7500 - val_factorized_top_k/top_10_categorical_accuracy: 0.7500 - val_factorized_top_k/top_50_categorical_accuracy: 1.0000 - val_factorized_top_k/top_100_categorical_accuracy: 1.0000 - val_loss: 0.7318 - val_regularization_loss: 0.0000e+00 - val_total_loss: 0.7318 - lr: 5.0000e-04
# Epoch 34/100
# 3/3 [==============================] - ETA: 0s - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0938 - factorized_top_k/top_50_categorical_accuracy: 1.0000 - factorized_top_k/top_100_categorical_accuracy: 1.0000 - loss: 55.4145 - regularization_loss: 0.0000e+00 - total_loss: 55.4145
# Epoch 34: val_loss did not improve from 0.17289
# 3/3 [==============================] - 1s 350ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0938 - factorized_top_k/top_50_categorical_accuracy: 1.0000 - factorized_top_k/top_100_categorical_accuracy: 1.0000 - loss: 55.2755 - regularization_loss: 0.0000e+00 - total_loss: 55.2755 - val_factorized_top_k/top_1_categorical_accuracy: 0.2500 - val_factorized_top_k/top_5_categorical_accuracy: 0.2500 - val_factorized_top_k/top_10_categorical_accuracy: 0.2500 - val_factorized_top_k/top_50_categorical_accuracy: 1.0000 - val_factorized_top_k/top_100_categorical_accuracy: 1.0000 - val_loss: 1.4056 - val_regularization_loss: 0.0000e+00 - val_total_loss: 1.4056 - lr: 2.5000e-04
# Epoch 35/100
# 3/3 [==============================] - ETA: 0s - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.1146 - factorized_top_k/top_50_categorical_accuracy: 1.0000 - factorized_top_k/top_100_categorical_accuracy: 1.0000 - loss: 56.6240 - regularization_loss: 0.0000e+00 - total_loss: 56.6240
# Epoch 35: val_loss did not improve from 0.17289
# 3/3 [==============================] - 1s 356ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.1146 - factorized_top_k/top_50_categorical_accuracy: 1.0000 - factorized_top_k/top_100_categorical_accuracy: 1.0000 - loss: 56.2968 - regularization_loss: 0.0000e+00 - total_loss: 56.2968 - val_factorized_top_k/top_1_categorical_accuracy: 0.7500 - val_factorized_top_k/top_5_categorical_accuracy: 0.7500 - val_factorized_top_k/top_10_categorical_accuracy: 1.0000 - val_factorized_top_k/top_50_categorical_accuracy: 1.0000 - val_factorized_top_k/top_100_categorical_accuracy: 1.0000 - val_loss: 2.0530 - val_regularization_loss: 0.0000e+00 - val_total_loss: 2.0530 - lr: 2.5000e-04
# Epoch 36/100
# 3/3 [==============================] - ETA: 0s - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.1146 - factorized_top_k/top_50_categorical_accuracy: 1.0000 - factorized_top_k/top_100_categorical_accuracy: 1.0000 - loss: 55.2273 - regularization_loss: 0.0000e+00 - total_loss: 55.2273
# Epoch 36: val_loss improved from 0.17289 to 0.02465, saving model to checkpoints\model_best.weights.h5
# 3/3 [==============================] - 1s 367ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.1146 - factorized_top_k/top_50_categorical_accuracy: 1.0000 - factorized_top_k/top_100_categorical_accuracy: 1.0000 - loss: 54.7924 - regularization_loss: 0.0000e+00 - total_loss: 54.7924 - val_factorized_top_k/top_1_categorical_accuracy: 0.5000 - val_factorized_top_k/top_5_categorical_accuracy: 0.5000 - val_factorized_top_k/top_10_categorical_accuracy: 0.7500 - val_factorized_top_k/top_50_categorical_accuracy: 1.0000 - val_factorized_top_k/top_100_categorical_accuracy: 1.0000 - val_loss: 0.0246 - val_regularization_loss: 0.0000e+00 - val_total_loss: 0.0246 - lr: 2.5000e-04
# Epoch 37/100
# 3/3 [==============================] - ETA: 0s - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.1146 - factorized_top_k/top_50_categorical_accuracy: 1.0000 - factorized_top_k/top_100_categorical_accuracy: 1.0000 - loss: 53.7097 - regularization_loss: 0.0000e+00 - total_loss: 53.7097
# Epoch 37: val_loss did not improve from 0.02465
# 3/3 [==============================] - 1s 341ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.1146 - factorized_top_k/top_50_categorical_accuracy: 1.0000 - factorized_top_k/top_100_categorical_accuracy: 1.0000 - loss: 53.2929 - regularization_loss: 0.0000e+00 - total_loss: 53.2929 - val_factorized_top_k/top_1_categorical_accuracy: 1.0000 - val_factorized_top_k/top_5_categorical_accuracy: 1.0000 - val_factorized_top_k/top_10_categorical_accuracy: 1.0000 - val_factorized_top_k/top_50_categorical_accuracy: 1.0000 - val_factorized_top_k/top_100_categorical_accuracy: 1.0000 - val_loss: 1.3911 - val_regularization_loss: 0.0000e+00 - val_total_loss: 1.3911 - lr: 2.5000e-04
# Epoch 38/100
# 3/3 [==============================] - ETA: 0s - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.1146 - factorized_top_k/top_50_categorical_accuracy: 1.0000 - factorized_top_k/top_100_categorical_accuracy: 1.0000 - loss: 52.3259 - regularization_loss: 0.0000e+00 - total_loss: 52.3259
# Epoch 38: val_loss improved from 0.02465 to 0.00314, saving model to checkpoints\model_best.weights.h5
# 3/3 [==============================] - 1s 365ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.1146 - factorized_top_k/top_50_categorical_accuracy: 1.0000 - factorized_top_k/top_100_categorical_accuracy: 1.0000 - loss: 52.2671 - regularization_loss: 0.0000e+00 - total_loss: 52.2671 - val_factorized_top_k/top_1_categorical_accuracy: 0.2500 - val_factorized_top_k/top_5_categorical_accuracy: 0.2500 - val_factorized_top_k/top_10_categorical_accuracy: 0.5000 - val_factorized_top_k/top_50_categorical_accuracy: 1.0000 - val_factorized_top_k/top_100_categorical_accuracy: 1.0000 - val_loss: 0.0031 - val_regularization_loss: 0.0000e+00 - val_total_loss: 0.0031 - lr: 2.5000e-04
# Epoch 39/100
# 3/3 [==============================] - ETA: 0s - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.2083 - factorized_top_k/top_50_categorical_accuracy: 1.0000 - factorized_top_k/top_100_categorical_accuracy: 1.0000 - loss: 53.2391 - regularization_loss: 0.0000e+00 - total_loss: 53.2391
# Epoch 39: val_loss did not improve from 0.00314
# 3/3 [==============================] - 1s 369ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.2083 - factorized_top_k/top_50_categorical_accuracy: 1.0000 - factorized_top_k/top_100_categorical_accuracy: 1.0000 - loss: 53.5403 - regularization_loss: 0.0000e+00 - total_loss: 53.5403 - val_factorized_top_k/top_1_categorical_accuracy: 0.7500 - val_factorized_top_k/top_5_categorical_accuracy: 0.7500 - val_factorized_top_k/top_10_categorical_accuracy: 1.0000 - val_factorized_top_k/top_50_categorical_accuracy: 1.0000 - val_factorized_top_k/top_100_categorical_accuracy: 1.0000 - val_loss: 0.6317 - val_regularization_loss: 0.0000e+00 - val_total_loss: 0.6317 - lr: 2.5000e-04
# Epoch 40/100
# 3/3 [==============================] - ETA: 0s - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.1979 - factorized_top_k/top_50_categorical_accuracy: 1.0000 - factorized_top_k/top_100_categorical_accuracy: 1.0000 - loss: 51.8149 - regularization_loss: 0.0000e+00 - total_loss: 51.8149
# Epoch 40: val_loss did not improve from 0.00314
# 3/3 [==============================] - 1s 356ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.1979 - factorized_top_k/top_50_categorical_accuracy: 1.0000 - factorized_top_k/top_100_categorical_accuracy: 1.0000 - loss: 51.4168 - regularization_loss: 0.0000e+00 - total_loss: 51.4168 - val_factorized_top_k/top_1_categorical_accuracy: 0.7500 - val_factorized_top_k/top_5_categorical_accuracy: 0.7500 - val_factorized_top_k/top_10_categorical_accuracy: 0.7500 - val_factorized_top_k/top_50_categorical_accuracy: 1.0000 - val_factorized_top_k/top_100_categorical_accuracy: 1.0000 - val_loss: 2.5831 - val_regularization_loss: 0.0000e+00 - val_total_loss: 2.5831 - lr: 2.5000e-04
# Epoch 41/100
# 3/3 [==============================] - ETA: 0s - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.1875 - factorized_top_k/top_50_categorical_accuracy: 1.0000 - factorized_top_k/top_100_categorical_accuracy: 1.0000 - loss: 52.2069 - regularization_loss: 0.0000e+00 - total_loss: 52.2069
# Epoch 41: val_loss did not improve from 0.00314
# 3/3 [==============================] - 1s 349ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.1875 - factorized_top_k/top_50_categorical_accuracy: 1.0000 - factorized_top_k/top_100_categorical_accuracy: 1.0000 - loss: 52.4695 - regularization_loss: 0.0000e+00 - total_loss: 52.4695 - val_factorized_top_k/top_1_categorical_accuracy: 0.7500 - val_factorized_top_k/top_5_categorical_accuracy: 0.7500 - val_factorized_top_k/top_10_categorical_accuracy: 1.0000 - val_factorized_top_k/top_50_categorical_accuracy: 1.0000 - val_factorized_top_k/top_100_categorical_accuracy: 1.0000 - val_loss: 3.2958 - val_regularization_loss: 0.0000e+00 - val_total_loss: 3.2958 - lr: 2.5000e-04
# Epoch 42/100
# 3/3 [==============================] - ETA: 0s - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.2083 - factorized_top_k/top_50_categorical_accuracy: 1.0000 - factorized_top_k/top_100_categorical_accuracy: 1.0000 - loss: 50.8783 - regularization_loss: 0.0000e+00 - total_loss: 50.8783
# Epoch 42: val_loss did not improve from 0.00314
# 3/3 [==============================] - 1s 354ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.2083 - factorized_top_k/top_50_categorical_accuracy: 1.0000 - factorized_top_k/top_100_categorical_accuracy: 1.0000 - loss: 50.8845 - regularization_loss: 0.0000e+00 - total_loss: 50.8845 - val_factorized_top_k/top_1_categorical_accuracy: 0.2500 - val_factorized_top_k/top_5_categorical_accuracy: 0.2500 - val_factorized_top_k/top_10_categorical_accuracy: 0.5000 - val_factorized_top_k/top_50_categorical_accuracy: 1.0000 - val_factorized_top_k/top_100_categorical_accuracy: 1.0000 - val_loss: 1.3348 - val_regularization_loss: 0.0000e+00 - val_total_loss: 1.3348 - lr: 2.5000e-04
# Epoch 43/100
# 3/3 [==============================] - ETA: 0s - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.2083 - factorized_top_k/top_50_categorical_accuracy: 1.0000 - factorized_top_k/top_100_categorical_accuracy: 1.0000 - loss: 51.2573 - regularization_loss: 0.0000e+00 - total_loss: 51.2573
# Epoch 43: val_loss did not improve from 0.00314
#
# Epoch 43: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 3/3 [==============================] - 1s 354ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.2083 - factorized_top_k/top_50_categorical_accuracy: 1.0000 - factorized_top_k/top_100_categorical_accuracy: 1.0000 - loss: 51.1165 - regularization_loss: 0.0000e+00 - total_loss: 51.1165 - val_factorized_top_k/top_1_categorical_accuracy: 1.0000 - val_factorized_top_k/top_5_categorical_accuracy: 1.0000 - val_factorized_top_k/top_10_categorical_accuracy: 1.0000 - val_factorized_top_k/top_50_categorical_accuracy: 1.0000 - val_factorized_top_k/top_100_categorical_accuracy: 1.0000 - val_loss: 3.2958 - val_regularization_loss: 0.0000e+00 - val_total_loss: 3.2958 - lr: 2.5000e-04
# Epoch 44/100
# 3/3 [==============================] - ETA: 0s - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.1979 - factorized_top_k/top_50_categorical_accuracy: 1.0000 - factorized_top_k/top_100_categorical_accuracy: 1.0000 - loss: 50.5409 - regularization_loss: 0.0000e+00 - total_loss: 50.5409
# Epoch 44: val_loss did not improve from 0.00314
# 3/3 [==============================] - 1s 350ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.1979 - factorized_top_k/top_50_categorical_accuracy: 1.0000 - factorized_top_k/top_100_categorical_accuracy: 1.0000 - loss: 50.3955 - regularization_loss: 0.0000e+00 - total_loss: 50.3955 - val_factorized_top_k/top_1_categorical_accuracy: 0.5000 - val_factorized_top_k/top_5_categorical_accuracy: 0.5000 - val_factorized_top_k/top_10_categorical_accuracy: 0.5000 - val_factorized_top_k/top_50_categorical_accuracy: 1.0000 - val_factorized_top_k/top_100_categorical_accuracy: 1.0000 - val_loss: 0.1800 - val_regularization_loss: 0.0000e+00 - val_total_loss: 0.1800 - lr: 1.2500e-04
# Epoch 45/100
# 3/3 [==============================] - ETA: 0s - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.2708 - factorized_top_k/top_50_categorical_accuracy: 1.0000 - factorized_top_k/top_100_categorical_accuracy: 1.0000 - loss: 49.1914 - regularization_loss: 0.0000e+00 - total_loss: 49.1914
# Epoch 45: val_loss did not improve from 0.00314
# 3/3 [==============================] - 1s 357ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.2708 - factorized_top_k/top_50_categorical_accuracy: 1.0000 - factorized_top_k/top_100_categorical_accuracy: 1.0000 - loss: 48.9698 - regularization_loss: 0.0000e+00 - total_loss: 48.9698 - val_factorized_top_k/top_1_categorical_accuracy: 0.2500 - val_factorized_top_k/top_5_categorical_accuracy: 0.2500 - val_factorized_top_k/top_10_categorical_accuracy: 0.5000 - val_factorized_top_k/top_50_categorical_accuracy: 1.0000 - val_factorized_top_k/top_100_categorical_accuracy: 1.0000 - val_loss: 1.3878 - val_regularization_loss: 0.0000e+00 - val_total_loss: 1.3878 - lr: 1.2500e-04
# Epoch 46/100
# 3/3 [==============================] - ETA: 0s - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.2708 - factorized_top_k/top_50_categorical_accuracy: 1.0000 - factorized_top_k/top_100_categorical_accuracy: 1.0000 - loss: 48.9294 - regularization_loss: 0.0000e+00 - total_loss: 48.9294
# Epoch 46: val_loss did not improve from 0.00314
# 3/3 [==============================] - 1s 361ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.2708 - factorized_top_k/top_50_categorical_accuracy: 1.0000 - factorized_top_k/top_100_categorical_accuracy: 1.0000 - loss: 49.2089 - regularization_loss: 0.0000e+00 - total_loss: 49.2089 - val_factorized_top_k/top_1_categorical_accuracy: 1.0000 - val_factorized_top_k/top_5_categorical_accuracy: 1.0000 - val_factorized_top_k/top_10_categorical_accuracy: 1.0000 - val_factorized_top_k/top_50_categorical_accuracy: 1.0000 - val_factorized_top_k/top_100_categorical_accuracy: 1.0000 - val_loss: 1.6589 - val_regularization_loss: 0.0000e+00 - val_total_loss: 1.6589 - lr: 1.2500e-04
# Epoch 47/100
# 3/3 [==============================] - ETA: 0s - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.2708 - factorized_top_k/top_50_categorical_accuracy: 1.0000 - factorized_top_k/top_100_categorical_accuracy: 1.0000 - loss: 50.9964 - regularization_loss: 0.0000e+00 - total_loss: 50.9964
# Epoch 47: val_loss did not improve from 0.00314
# 3/3 [==============================] - 1s 352ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.2708 - factorized_top_k/top_50_categorical_accuracy: 1.0000 - factorized_top_k/top_100_categorical_accuracy: 1.0000 - loss: 50.7533 - regularization_loss: 0.0000e+00 - total_loss: 50.7533 - val_factorized_top_k/top_1_categorical_accuracy: 1.0000 - val_factorized_top_k/top_5_categorical_accuracy: 1.0000 - val_factorized_top_k/top_10_categorical_accuracy: 1.0000 - val_factorized_top_k/top_50_categorical_accuracy: 1.0000 - val_factorized_top_k/top_100_categorical_accuracy: 1.0000 - val_loss: 1.6468 - val_regularization_loss: 0.0000e+00 - val_total_loss: 1.6468 - lr: 1.2500e-04
# Epoch 48/100
# 3/3 [==============================] - ETA: 0s - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.2604 - factorized_top_k/top_50_categorical_accuracy: 1.0000 - factorized_top_k/top_100_categorical_accuracy: 1.0000 - loss: 49.0635 - regularization_loss: 0.0000e+00 - total_loss: 49.0635
# Epoch 48: val_loss did not improve from 0.00314
# Restoring model weights from the end of the best epoch: 38.
#
# Epoch 48: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 3/3 [==============================] - 1s 370ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.2604 - factorized_top_k/top_50_categorical_accuracy: 1.0000 - factorized_top_k/top_100_categorical_accuracy: 1.0000 - loss: 48.6479 - regularization_loss: 0.0000e+00 - total_loss: 48.6479 - val_factorized_top_k/top_1_categorical_accuracy: 0.5000 - val_factorized_top_k/top_5_categorical_accuracy: 0.5000 - val_factorized_top_k/top_10_categorical_accuracy: 0.7500 - val_factorized_top_k/top_50_categorical_accuracy: 1.0000 - val_factorized_top_k/top_100_categorical_accuracy: 1.0000 - val_loss: 0.9696 - val_regularization_loss: 0.0000e+00 - val_total_loss: 0.9696 - lr: 1.2500e-04
# Epoch 48: early stopping
# Loaded best weights from checkpoints\model_best.weights.h5
# Training completed!

# %%
# Load best weights if available
checkpoint_path = 'checkpoints/model_best.weights.h5'
if os.path.exists(checkpoint_path):
    model.load_weights(checkpoint_path)
    print(f"Loaded best weights from {checkpoint_path}")
else:
    print("No checkpoint found, using current model weights")

# Display recommendations for a specific investor
investor_id = '0026147b-6cf0-4f4b-9bc4-fe86f28c3df8'  # Replace with a valid UUID from investor_df
top_k = 5
display_recommendations(investor_id=investor_id, top_k=top_k)
# Out:
# Loaded best weights from checkpoints/model_best.weights.h5
#
# === Recommendations for Investor 0026147b-6cf0-4f4b-9bc4-fe86f28c3df8 ===
# Investor preferences:
#   Location: jawa
#   Category: retail
#   Category: b2c
#   Scale: mikro
#   Jangkauan: internasional
#
# Top 5 recommended UMKMs:
# 1. UMKM 313d2bc3-eaf8-4beb-925d-777095ee9db5 (Score: 0.904)
#    Category: teknologi
#    Location: Yogyakarta, DI Yogyakarta
#    Business model: dropship
#    Skala usaha: mikro
#    Jangkauan: nasional
#    Pertumbuhan pendapatan: 0.23%
#
# 2. UMKM 62767b5d-8b8f-4f14-b1e4-e5829b3204ce (Score: 0.904)
#    Category: kuliner
#    Location: Yogyakarta, DI Yogyakarta
#    Business model: b2c
#    Skala usaha: kecil
#    Jangkauan: lokal
#    Pertumbuhan pendapatan: 0.48%
#
# 3. UMKM 8c1bd284-e129-4d8d-a610-29ba2806895d (Score: 0.904)
#    Category: kuliner
#    Location: Yogyakarta, DI Yogyakarta
#    Business model: dropship
#    Skala usaha: kecil
#    Jangkauan: regional
#    Pertumbuhan pendapatan: 0.26%
#
# 4. UMKM b3174faa-de30-43be-801a-cf97fce55661 (Score: 0.904)
#    Category: pendidikan
#    Location: Yogyakarta, DI Yogyakarta
#    Business model: franchise
#    Skala usaha: mikro
#    Jangkauan: nasional
#    Pertumbuhan pendapatan: 0.13%
#
# 5. UMKM c8a9d514-f647-40d8-8f1a-65f03cc5d6ab (Score: 0.904)
#    Category: retail
#    Location: Yogyakarta, DI Yogyakarta
#    Business model: direct-to-consumer
#    Skala usaha: menengah
#    Jangkauan: internasional
#    Pertumbuhan pendapatan: 0.26%
